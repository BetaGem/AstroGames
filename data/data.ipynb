# %%
from astropy.io import ascii
from astropy.table import Table

# %%
cat = ascii.read("./hip_main.dat", readme="./ReadMe.txt")

# %%
cat.write("./hip_main.csv", format="csv", overwrite=True)

# %%
cat = Table.read("hip_main.csv", format="csv")
# Out:
# <Table length=517>
# Catalog  HIP   Proxy    RAhms    ...    CPD     (V-I)red    SpType   r_SpType
#   str1  int64   str1    str11    ...   str10    float64     str12      str1
# ------- ------ ----- ----------- ... ---------- -------- ----------- --------
#       H    677    -- 00 08 23.17 ...         --     -0.1         B9p        X
#       H    746    -- 00 09 10.09 ...         --      0.4    F2III-IV        X
#       H    765    -- 00 09 24.54 ... P-46     7      1.0       K0III        X
#       H   1067    -- 00 13 14.15 ...         --    -0.22        B2IV        X
#       H   1562    -- 00 19 25.68 ...         --     1.13       K2III        X
#       H   2021    -- 00 25 39.20 ... P-77    16     0.68        G2IV        X
#       H   2072    -- 00 26 12.12 ... P-44    47      0.2         A7V        X
#       H   2081    -- 00 26 16.87 ... P-42    34     1.11    K0III...        X
#       H   2920    -- 00 36 58.27 ...         --    -0.23        B2IV        X
# ...

# %%
catb = cat[cat['Vmag'] < 4]

# %%
t = Table(catb['HIP', 'RAdeg', 'DEdeg', 'Vmag', 'B-V'])
t.write("./hip_bright.csv", format="csv", overwrite=True)

# %%
t
# Out:
# <Table length=517>
#  HIP      RAdeg        DEdeg       Vmag    B-V
# int64    float64      float64    float64 float64
# ------ ------------ ------------ ------- -------
#    677   2.09653333  29.09082805    2.07  -0.038
#    746   2.29204036  59.15021814    2.28    0.38
#    765   2.35224949 -45.74698836    3.88   1.013
#   1067   3.30895828  15.18361593    2.83   -0.19
#   1562   4.85701265  -8.82382948    3.56   1.214
#   2021   6.41334183 -77.25503511    2.82   0.618
#   2072   6.55048418 -43.67990933    3.93   0.175
#   2081   6.57028075 -42.30512197     2.4   1.083
#   2920   9.24277921  53.89693161    3.69  -0.196
#    ...          ...          ...     ...     ...
# 113726 345.48019377  42.32597866    3.62  -0.099
# 113881 345.94305575  28.08245462    2.44   1.655
# 113963  346.1900702  15.20536786    2.49  -0.002
# 114341 347.36150879 -21.17248555    3.68   1.202
# 114421 347.58928308 -45.24664747    3.88   0.998
# 114971 349.28955677   3.28224524     3.7   0.916
# ...
